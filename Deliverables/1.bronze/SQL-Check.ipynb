# %%
# %sql
SELECT * FROM read_files(
  '/Volumes/zara-lakehouse/retail-source/discount/discount.csv',
  format => 'csv',
  header => true)

# %%
# %sql
SELECT * FROM read_files(
  '/Volumes/zara-lakehouse/retail-source/products_sold/products_sold.csv',
  format => 'csv',
  header => true)

# %%
# %sql
SELECT * FROM read_files(
  '/Volumes/zara-lakehouse/retail-source/product_information/product_information.csv',
  format => 'csv',
  header => true)
