# %%
from pyspark.sql import functions as F

# %%
path = '/Volumes/zara-lakehouse/retail-source/product_information/product_information.csv'
df = spark.read \
    .option("header", True) \
    .option("inferSchema", True) \
    .csv(path)

display(df)

# %%
duplicates_df = df.groupBy("Product ID") \
    .count() \
    .filter("count > 1")

# %%
display(duplicates_df)
