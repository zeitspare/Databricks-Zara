# %%
# %sql
select * from zara_lakehouse.retail_bronze.discount_bronze

# %%
from pyspark.sql import functions as F
from pyspark.sql.window import Window

# %%
bronze_path = 'zara_lakehouse.retail_bronze.discount_bronze'

# %%
df = spark.read. \
    .option("header", True) \
    .option("inferSchema", True) \
    .csv(path)

display(df)

# %%
duplicates_df = df.groupBy("Product ID", "city") \
    .count() \
    .filter("count > 1")

# %%
display(duplicates_df)

# %%
df_filtered = df \
             .filter(F.col("Product ID") == 113143)  \
             .filter(F.col("city") == "San Antonio") \
             .select("Product ID", "city", "discount")
    
display(df_filtered)
