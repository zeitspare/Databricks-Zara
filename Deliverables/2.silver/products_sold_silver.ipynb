# %%
# %sql
select * from zara_lakehouse.retail_bronze.products_sold_bronze

# %%
from pyspark.sql import functions as F

# %%
path = '/Volumes/zara-lakehouse/retail-source/products_sold/products_sold.csv'
df = spark.read \
    .option("header", True) \
    .option("inferSchema", True) \
    .csv(path)

display(df)

# %%
duplicates_df = df.groupBy("Product ID", "city") \
    .count() \
    .filter("count > 1")

# %%
display(duplicates_df)

# %%
time_df = df.withColumn("date", F.to_timestamp(F.col("time"), "yyyy-MM-dd")) \
    #.withColumn("time", F.unix_timestamp(F.col("time"), "yyyy-MM-dd"))

# %%
display(time_df)
