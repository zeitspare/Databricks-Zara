# %%
# %sql
DROP TABLE IF EXISTS zara_lakehouse.retail_gold.gold_city_sales;

# %%
# %sql
DROP TABLE IF EXISTS zara_lakehouse.retail_gold.gold_fact_sales;

# %%
# %sql
DROP TABLE IF EXISTS zara_lakehouse.retail_gold.gold_product_attribute_sales;

# %%
# %sql
DROP TABLE IF EXISTS zara_lakehouse.retail_gold.gold_product_sales;
