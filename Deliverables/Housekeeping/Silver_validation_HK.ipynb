# %%
# %sql
DROP TABLE IF EXISTS zara_lakehouse.retail_quarantine.dim_discount_qt;

# %%
# %sql
DROP TABLE IF EXISTS zara_lakehouse.retail_quarantine.dim_product_information_qt;

# %%
# %sql
DROP TABLE IF EXISTS zara_lakehouse.retail_quarantine.dim_products_sold_qt;

# %%
# %sql
DROP TABLE IF EXISTS zara_lakehouse.retail_validation.dim_discount_dq

# %%
# %sql
DROP TABLE IF EXISTS zara_lakehouse.retail_validation.dim_product_information_dq;

# %%
# %sql
DROP TABLE IF EXISTS zara_lakehouse.retail_validation.dim_products_sold_dq;
