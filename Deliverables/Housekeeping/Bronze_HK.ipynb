# %%
# %sql
DROP TABLE IF EXISTS zara_lakehouse.retail_bronze.discount_bronze;

# %%
# %sql
DROP TABLE IF EXISTS zara_lakehouse.retail_bronze.product_information_bronze;

# %%
# %sql
DROP TABLE IF EXISTS zara_lakehouse.retail_bronze.products_sold_bronze;
