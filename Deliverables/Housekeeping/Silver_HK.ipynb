# %%
# %sql
DROP TABLE IF EXISTS zara_lakehouse.retail_silver.fact_sales_silver;

# %%
# %sql
DROP TABLE IF EXISTS zara_lakehouse.retail_silver.dim_discount_silver;

# %%
# %sql
DROP TABLE IF EXISTS zara_lakehouse.retail_silver.dim_product_information_silver;

# %%
# %sql
DROP TABLE IF EXISTS zara_lakehouse.retail_silver.dim_products_sold_silver;
